# %%
import os
import pandas as pd
import glob
from matplotlib import pyplot as plt
from matplotlib.ticker import EngFormatter
ROWS=67


def draw(measured,sim_path):
    """draw func draw measured data vs simulated data

    Args:
        measured (list[str]): measured files paths
        simulated (list[str]): simulated files paths
    """    
    print("measured is blue")
    print("simulated is red")
    df1 = pd.read_csv(measured)
    for i in range(int(len(df1)/ROWS)):
        df=pd.DataFrame()    
        space = sim_path[i].rfind("/")
        read_dev_name = sim_path[i][space + 1:]

        df[0]=df1[df1.columns[0]][i*ROWS:(i+1)*ROWS]
        df[df1.columns[1:7]]=df1[df1.columns[1:7]][i*ROWS:(i+1)*ROWS]
        ax = df.plot(x=df.columns[0], y=df.columns[1:7], color="r", figsize=(15,12))
        volt_formatter = EngFormatter(unit='V')
        amp_formatter = EngFormatter(unit='A')
        ax.xaxis.set_major_formatter(volt_formatter)
        ax.yaxis.set_major_formatter(amp_formatter)
        df[0]=df1[df1.columns[0]][i*ROWS:(i+1)*ROWS]
        df[df1.columns[7:13]]=df1[df1.columns[7:13]][i*ROWS:(i+1)*ROWS]
        df.plot(ax=ax, x=df.columns[0], y=df.columns[7:13], color="b")
        plt.grid()
        plt.xlabel('Vds')
        plt.ylabel('Drain Current')
        plt.title(read_dev_name)        
    plt.show()

device =  [
        "nfet_03v3",
        "pfet_03v3",
        "nfet_06v0",
        "pfet_06v0",
        "nfet_06v0_nvt",
        "nfet_03v3_dss",
        "pfet_03v3_dss",
        "nfet_06v0_dss",
        "pfet_06v0_dss"
    ]

dev=0
measured = (f"mos_iv_regr/{device[dev]}/error_analysis_Id.csv")
sim_path = glob.glob(f"mos_iv_regr/{device[dev]}/{device[dev]}_netlists_Id/*.csv")
draw(measured,sim_path)

# %%
import os
import pandas as pd
import glob
from matplotlib import pyplot as plt
from matplotlib.ticker import EngFormatter
ROWS=67


def draw(measured,sim_path):
    """draw func draw measured data vs simulated data

    Args:
        measured (list[str]): measured files paths
        simulated (list[str]): simulated files paths
    """    
    print("measured is blue")
    print("simulated is red")
    df1 = pd.read_csv(measured)
    for i in range(int(len(df1)/ROWS)):
        df=pd.DataFrame()    
        space = sim_path[i].rfind("/")
        read_dev_name = sim_path[i][space + 1:]

        df[0]=df1[df1.columns[0]][i*ROWS:(i+1)*ROWS]
        df[df1.columns[1:7]]=df1[df1.columns[1:7]][i*ROWS:(i+1)*ROWS]
        ax = df.plot(x=df.columns[0], y=df.columns[1:7], color="r", figsize=(15,12))
        volt_formatter = EngFormatter(unit='V')
        amp_formatter = EngFormatter(unit='Ohm')
        ax.xaxis.set_major_formatter(volt_formatter)
        ax.yaxis.set_major_formatter(amp_formatter)
        df[0]=df1[df1.columns[0]][i*ROWS:(i+1)*ROWS]
        df[df1.columns[7:13]]=df1[df1.columns[7:13]][i*ROWS:(i+1)*ROWS]
        df.plot(ax=ax, x=df.columns[0], y=df.columns[7:13], color="b")
        plt.grid()
        plt.xlabel('Vds')
        plt.ylabel('Rds')
        plt.title(read_dev_name)        
    plt.show()

device =  [
        "nfet_03v3",
        "pfet_03v3",
        "nfet_06v0",
        "pfet_06v0",
        "nfet_06v0_nvt",
        "nfet_03v3_dss",
        "pfet_03v3_dss",
        "nfet_06v0_dss",
        "pfet_06v0_dss"
    ]

dev=0
measured = (f"mos_iv_regr/{device[dev]}/error_analysis_Rds.csv")
sim_path = glob.glob(f"mos_iv_regr/{device[dev]}/{device[dev]}_netlists_Rds/*.csv")
draw(measured,sim_path)
# Out:
# measured is blue
# simulated is red
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /home/farag/Team_mabrains/mabrains_gf180mcu/globalfoundries-pdk-libs-gf180mcu_fd_pr/models/ngspice/testing/regression/mos_iv_vgs/plotting.ipynb Cell 2 in <cell line: 55>()
#      <a href='vscode-notebook-cell:/home/farag/Team_mabrains/mabrains_gf180mcu/globalfoundries-pdk-libs-gf180mcu_fd_pr/models/ngspice/testing/regression/mos_iv_vgs/plotting.ipynb#W1sZmlsZQ%3D%3D?line=52'>53</a> measured = (f"mos_iv_regr/{device[dev]}/error_analysis_Rds.csv")
#      <a href='vscode-notebook-cell:/home/farag/Team_mabrains/mabrains_gf180mcu/globalfoundries-pdk-libs-gf180mcu_fd_pr/models/ngspice/testing/regression/mos_iv_vgs/plotting.ipynb#W1sZmlsZQ%3D%3D?line=53'>54</a> sim_path = glob.glob(f"mos_iv_regr/{device[dev]}/{device[dev]}_netlists_Rds/*W10_L10*.csv")
# ---> <a href='vscode-notebook-cell:/home/farag/Team_mabrains/mabrains_gf180mcu/globalfoundries-pdk-libs-gf180mcu_fd_pr/models/ngspice/testing/regression/mos_iv_vgs/plotting.ipynb#W1sZmlsZQ%3D%3D?line=54'>55</a> draw(measured,sim_path)
#
# /home/farag/Team_mabrains/mabrains_gf180mcu/globalfoundries-pdk-libs-gf180mcu_fd_pr/models/ngspice/testing/regression/mos_iv_vgs/plotting.ipynb Cell 2 in draw(measured, sim_path)
#      <a href='vscode-notebook-cell:/home/farag/Team_mabrains/mabrains_gf180mcu/globalfoundries-pdk-libs-gf180mcu_fd_pr/models/ngspice/testing/regression/mos_iv_vgs/plotting.ipynb#W1sZmlsZQ%3D%3D?line=18'>19</a> for i in range(int(len(df1)/ROWS)):
#      <a href='vscode-notebook-cell:/home/farag/Team_mabrains/mabrains_gf180mcu/globalfoundries-pdk-libs-gf180mcu_fd_pr/models/ngspice/testing/regression/mos_iv_vgs/plotting.ipynb#W1sZmlsZQ%3D%3D?line=19'>20</a>     df=pd.DataFrame()
# ---> <a href='vscode-notebook-cell:/home/farag/Team_mabrains/mabrains_gf180mcu/globalfoundries-pdk-libs-gf180mcu_fd_pr/models/ngspice/testing/regression/mos_iv_vgs/plotting.ipynb#W1sZmlsZQ%3D%3D?line=20'>21</a>     space = sim_path[i].rfind("/")
#      <a href='vscode-notebook-cell:/home/farag/Team_mabrains/mabrains_gf180mcu/globalfoundries-pdk-libs-gf180mcu_fd_pr/models/ngspice/testing/regression/mos_iv_vgs/plotting.ipynb#W1sZmlsZQ%3D%3D?line=21'>22</a>     read_dev_name = sim_path[i][space + 1:]
#      <a href='vscode-notebook-cell:/home/farag/Team_mabrains/mabrains_gf180mcu/globalfoundries-pdk-libs-gf180mcu_fd_pr/models/ngspice/testing/regression/mos_iv_vgs/plotting.ipynb#W1sZmlsZQ%3D%3D?line=23'>24</a>     df[0]=df1[df1.columns[0]][i*ROWS:(i+1)*ROWS]
#
# IndexError: list index out of range
